# %%
# !pip install pandas

# %%
import pandas as pd
import pymongo

# Connection to MongoDB
client = pymongo.MongoClient("mongodb://localhost:27017")

# Specify the database and collection
db = client['audio-app']
collection = db['predictions']

# Find all documents in the collection and convert to a list of dictionaries
documents = list(collection.find())

# Close the MongoDB connection
client.close()

# Convert the list of dictionaries to a Pandas DataFrame
df = pd.DataFrame(documents)

# Print the DataFrame

# %%
df.sort_values(by='predicted_at', ascending=False).head(20)
# Out:
#                            _id  class_ids class_names  predictions  \
# 2057  6579e45ac4af703571cefc80          1   Non-Audio        99.81
# 2056  6579e454c4af703571cefc7f          1   Non-Audio        99.90
# 2055  6579e44fc4af703571cefc7e          1   Non-Audio        99.95
# 2054  6579e449c4af703571cefc7d          1   Non-Audio        99.59
# 2053  6579e446c4af703571cefc7c          2   Non-Break        99.93
# 2052  6579e442c4af703571cefc7b          2   Non-Break        95.79
# 2051  6579e433c4af703571cefc7a          1   Non-Audio        97.46
# 2050  6579e431c4af703571cefc79          1   Non-Audio        99.96
# 2049  6579e42ec4af703571cefc78          1   Non-Audio        95.64
# 2048  6579e42cc4af703571cefc77          1   Non-Audio        99.95
# 2047  6579e3c4c4af703571cefc76          2   Non-Break        98.89
# 2046  6579e3c1c4af703571cefc75          2   Non-Break       100.00
# 2045  6579e3bfc4af703571cefc74          2   Non-Break        93.04
# 2044  6579e3bdc4af703571cefc73          2   Non-Break        99.92
# 2043  6579e3bbc4af703571cefc72          1   Non-Audio        99.95
# 2042  6579e3b8c4af703571cefc71          1   Non-Audio        99.95
# 2041  6579e3b6c4af703571cefc70          2   Non-Break        94.44
# 2040  6579e3b2c4af703571cefc6f          1   Non-Audio        98.43
# 2039  6579e3b0c4af703571cefc6e          1   Non-Audio        99.92
# 2038  6579e3aec4af703571cefc6d          2   Non-Break        95.47
#
#       inference_time         predicted_at  \
# 2057        0.027738  12-14-2023 00:05:30
# 2056        0.019547  12-14-2023 00:05:24
# 2055        0.024468  12-14-2023 00:05:19
# 2054        0.029216  12-14-2023 00:05:13
# 2053        0.023999  12-14-2023 00:05:10
# 2052        0.027016  12-14-2023 00:05:06
# 2051        0.017110  12-14-2023 00:04:51
# 2050        0.029847  12-14-2023 00:04:49
# 2049        0.025556  12-14-2023 00:04:46
# 2048        0.036833  12-14-2023 00:04:44
# 2047        0.024113  12-14-2023 00:03:00
# 2046        0.020481  12-14-2023 00:02:57
# 2045        0.018017  12-14-2023 00:02:55
# 2044        0.023363  12-14-2023 00:02:53
# 2043        0.030368  12-14-2023 00:02:51
# 2042        0.026002  12-14-2023 00:02:48
# 2041        0.028481  12-14-2023 00:02:46
# 2040        0.026172  12-14-2023 00:02:42
# 2039        0.023992  12-14-2023 00:02:40
# 2038        0.023708  12-14-2023 00:02:38
#
#                                   file_path  yn
# 2057  public/audios/12-14-2023\00-05-30.wav   1
# 2056  public/audios/12-14-2023\00-05-24.wav   1
# 2055  public/audios/12-14-2023\00-05-19.wav   1
# 2054  public/audios/12-14-2023\00-05-13.wav   1
# 2053  public/audios/12-14-2023\00-05-10.wav   1
# 2052  public/audios/12-14-2023\00-05-06.wav   1
# 2051  public/audios/12-14-2023\00-04-51.wav   1
# 2050  public/audios/12-14-2023\00-04-49.wav   1
# 2049  public/audios/12-14-2023\00-04-46.wav   1
# 2048  public/audios/12-14-2023\00-04-44.wav   1
# 2047  public/audios/12-14-2023\00-03-00.wav   1
# 2046  public/audios/12-14-2023\00-02-57.wav   1
# 2045  public/audios/12-14-2023\00-02-55.wav   1
# 2044  public/audios/12-14-2023\00-02-53.wav   1
# 2043  public/audios/12-14-2023\00-02-51.wav   1
# 2042  public/audios/12-14-2023\00-02-48.wav   1
# 2041  public/audios/12-14-2023\00-02-46.wav   1
# 2040  public/audios/12-14-2023\00-02-42.wav   1
# 2039  public/audios/12-14-2023\00-02-40.wav   1
# 2038  public/audios/12-14-2023\00-02-38.wav   1
